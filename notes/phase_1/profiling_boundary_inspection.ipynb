# %%
import pandas as pd

# Contains profiling metrics for each note
profile_df = pd.read_csv("../../data/sample/profiling_per_note.csv")
# Contains raw text notes corresponding to the profiling data, indexed the same way
sample_df = pd.read_csv("../../data/sample/profiling_sample_500.csv")

# Define the lists of metrics to analyse
functional_metrics = [
    "colon_header_count",
    "uppercase_header_count",
    "numeric_token_count",
    "bp_pattern_count",
    "deid_token_count",
]

structural_metrics = [
    "char_length",
    "token_count",
    "line_count"
]

# ----------------------------
# 1. Collect functional metrics extremes
# ----------------------------

# Empty set to store unique indices of notes that are extreme in any metric
extreme_indices = set()

# Loop through each metric
for metric in functional_metrics:
    # Get top 5 and bottom 5 indices for the current metric
    top5 = profile_df.sort_values(metric, ascending=False).head(5).index
    bottom5 = profile_df.sort_values(metric).head(5).index
    
    # Add these indices to the set of extreme indices
    extreme_indices.update(top5)
    extreme_indices.update(bottom5)

print(f"Total unique extreme notes: {len(extreme_indices)}")

# ----------------------------
# 2. Collect structural metric extremes (char_length only)
# ----------------------------  

length_indices = set()

top2 = profile_df.sort_values("char_length", ascending=False).head(2).index
bottom2 = profile_df.sort_values("char_length").head(2).index

length_indices.update(top2)
length_indices.update(bottom2)

print(f"Total unique length-extreme notes: {len(length_indices)}")

all_extremes = extreme_indices.union(length_indices)
print(f"Total unique notes: {len(all_extremes)}")

# ----------------------------
# 3. Inspect each unique functional note
# ----------------------------

print("FUNCTIONAL EXTREMES:")

# Loop through each unique extreme index
for idx in extreme_indices:
    print("="*80)
    print(f"NOTE INDEX: {idx}")
    print(profile_df.loc[idx, functional_metrics])  # show all 5 functional metric values for the index
    print("-"*80)
    print(sample_df.loc[idx, "TEXT"])    # print raw note text
    print("\n\n")

# ----------------------------
# 4. Inspect each unique structural note
# ----------------------------

print("STRUCTURAL EXTREMES:")

for idx in length_indices:
    print("="*80)
    print(f"NOTE INDEX: {idx}")
    print(profile_df.loc[idx, structural_metrics])  # show all 3 structural metric values for the index
    print("-"*80)
    print(sample_df.loc[idx, "TEXT"])    # print raw note text
    print("\n\n")
# Out:
# Total unique extreme notes: 42
# Total unique length-extreme notes: 4
# 45
# FUNCTIONAL EXTREMES:
# ================================================================================
# NOTE INDEX: 0
# colon_header_count        17
# uppercase_header_count     0
# numeric_token_count       46
# bp_pattern_count           8
# deid_token_count           3
# Name: 0, dtype: int64
# --------------------------------------------------------------------------------
# The pt. is a 30y/o M with unknown PMH found down after reported heroin
#    use s/p cardiac arrest in the field. Per report EMS was called by a
#    friend reporting the pt became unresponsive after heroin and EtOH use.
#    The pt was found down after approx 10 minutes of unresponsiveness and
#    he received 30 minutes of CPR with initial rhythm asystole followed by
#    PEA. He received epi X2, atropine X2, HCO3 X2 and narcan 6 mg. He was
#    intbated in the field. Pt initially taken to [**Hospital 2653**] Hospital where intial
#    BP 58/22. Pt treated with IVF bolus and 2amp bicarb. Did not receive
#    pressors as BP rose to 140 following IVF. Pupils were fixed and
#    dilated. EtOH 265. Initial ABG 6.94/77/66/16. CT Head negative.
#    .
#    On arrival to the ED, vitals: HR 130, 150/100 and he was on the vent.
#    Neurologic exam on arrival included pupils fixed and non-reactive at
#    6mm. No withdrawal of extremities to pain. CXR showed ET in place. He
#    was started on the artic sun protocol. 2 PIV placed and he was started
#    on propofol for sedation. Initial ABG 7.41/24/172/16. Labs showed serum
#    EtOH of 198. Serum benzo screen positive. The patient had no
#    identifying information on arrival to the ED.
#    .
#     Events : patient is on artic sun protocol and patient was on propofol
#    and patient was having jerking movements, therefore sedation changed to
#    versed and Fentanyl and increased to versed 12mg/hr and Fentanyl
#    250mcg/hr and started on cisatracurium TOF 0/4. UO 10-45ml/hr and BP
#    170-180/109-112 with MAP 130-140, MD aware and continue to monitor.
#    .H/O cardiac arrest
#    Assessment:
#    Post cardiac arrest from OSH, received patient from ED with artic sun
#    protocol, in sinus rhythm, no ectopy
#    Action:
#    Artic sun protocol, core temp 34, goal temp 34, sedation changed from
#    propofol to versed and Fentanyl and increased versed to 12mg/hr and
#    Fentanyl 250 mcg/hr as patient had jerky movements and started on
#    cisatracurium. TOF [**1-25**] on 10ma with cisatracurium of 0.1/mg/kg. Trend
#    CE, repleted lytes
#    Response:
#    Sedated and paralysed, core temp 34, no shivering or jerky movements,
#    continue on cisatracurium
#    Plan:
#    Continue artic sun for 18-24 hrs, keep sedated and paralysed, monitor
#    lytes and labs
#    Respiratory failure, acute (not ARDS/[**Doctor Last Name 11**])
#    Assessment:
#    Received patient from ED sedated and vented, A/C mode, 450/12/5 and
#    40%, bilateral air entry clear
#    Action:
#    Sedation changed to versed and Fentanyl and patient is paralysed, O2
#    sats 100%. ABG
#    Response:
#    Unchanged
#    Plan:
#    Continue vent support until patient  is on artic sun, then wean
#    sedation and assess for extubation
#    Impaired Skin Integrity
#    Assessment:
#    Patient with severe psoriasis over both legs, elbows,  hands and
#    abdomen
#    Action:
#    None
#    Response:
#    Plan:
#    Obtain med list from family and start in AM
#    Anoxic brain damage (Anoxic encephalopathy, Hypoxic ischemic)
#    Assessment:
#    Patient arrived to ED from OSH following cardiac arrest with GCS 3, rt
#    pupil 4mm nonreacting, lt pupils surgical. patient received from ED
#    with propofol and sedation changed to versed and Fentanyl
#    Action:
#    Sedated and paralysed for artic sun protocol
#    Response:
#    Patient sedated and paralyses, unable to assess neuro
#    Plan:
#    When patient is off artic sun protocol , start wean sedation and assess
#    neuro check
#
#
#
#
# ================================================================================
# NOTE INDEX: 256
# colon_header_count         71
# uppercase_header_count     19
# numeric_token_count       432
# bp_pattern_count            4
# deid_token_count           66
# Name: 256, dtype: int64
# --------------------------------------------------------------------------------
# SICU
#    HPI:
#    45yo M w/EtOH cirrhosis, MELD 28, Child class C cirrhosis admitted for
#    liver transplant. Denies change in health since previous admission
#    8/[**2196**]. Admitted to [**Hospital1 5**] [**8-/2196**] for fevers, anemia, ascites, ARF.
#    Hospital course, treated w/Zosyn for C. perfringens bacteremia.
#    Paracentesis negative for SBP. EGD w/Grade I varices. ARF responded to
#    octreotide, midodrine.
#    Chief complaint:
#    Liver Failure
#    PMHx:
#    PMH: ([**7-21**]): EtOH cirrhosis, Gout, HTN now normotensive off meds , Gr 1
#    esophageal varices, C perfringens bacteremia.
#    .
#    PSH: remote appendectomy
#    .
#    [**Last Name (un) **]: Folic Acid 1, Thiamine HCl 100, Ursodiol 300''', Ranitidine
#    HCl 150'', lactulose, Furosemide 20, Spironolactone 100, Zofran
#    4, Maalox, Rifaximin 200'''
#    Current medications:
#    15. Morphine Sulfate 1-4 mg IV Q1H:PRN Pain  Order date: [**9-27**] @ 1715
#    16. Mycophenolate Mofetil Suspension 1000 mg PO/NG [**Hospital1 **]  Order date:
#    [**9-27**] @ 1715
#    3. Ampicillin-Sulbactam 3 gm IV Q6H Duration: 3 Doses Order date: [**9-27**]
#    @ 1715 17. Ondansetron 4 mg IV Q8H:PRN nausea/vomiting  Order date:
#    [**9-27**] @ 1715
#    4. Chlorhexidine Gluconate 0.12% Oral Rinse 15 ml ORAL [**Hospital1 **]
#    Use only if patient is on mechanical ventilation.  Order date: [**9-27**] @
#    1758 18. Pantoprazole 40 mg IV Q24H  Order date: [**9-27**] @ 1715
#    5. Docusate Sodium 100 mg PO/NG [**Hospital1 **]  Order date: [**9-27**] @ 1715 19.
#    Pamidronate 30 mg IV ONCE Duration: 1 Doses
#    POD #5  Order date: [**9-27**] @ 1715
#    6. Fluconazole 400 mg PO/NG Q24H  Order date: [**9-27**] @ 1715 20.
#    Pantoprazole 40 mg PO Q24H
#    Start when tolerating PO  Order date: [**9-27**] @ 1715
#    7. Furosemide 20 mg IV 2X
#    20 mg after 1st unit PRBC, 20 mg after 2nd  Order date: [**9-27**] @ [**2110**]
#    21. PredniSONE 35 mg PO ONCE Duration: 1 Doses
#    POD #5  Order date: [**9-27**] @ 1715
#    8. Furosemide 40 mg IV ONCE Duration: 1 Doses Order date: [**9-27**] @ 2227
#    22. PredniSONE 20 mg PO DAILY
#    POD #6 and ongoing  Order date: [**9-27**] @ 1715
#    23. Prochlorperazine 5-10 mg IV Q6H:PRN nausea  Order date: [**9-27**] @
#    1715
#    10. Insulin 100 Units/100 ml NS @ 5 UNIT/HR IV DRIP INFUSION
#    Fingersticks every hour  Order date: [**9-28**] @ 0240 24. Propofol [**6-1**]
#    mcg/kg/min IV DRIP TITRATE TO sedation, while intubated  Order date:
#    [**9-27**] @ 2158
#    11. MethylPREDNISolone Sodium Succ 200 mg IV ONCE Duration: 1 Doses
#    POD #1  Order date: [**9-27**] @ 1715 12. MethylPREDNISolone Sodium Succ 150
#    mg IV ONCE Duration: 1 Doses
#    POD #2  Order date: [**9-27**] @ 1715 26. Sodium Chloride 0.9% Flush 3 mL IV
#    13. MethylPREDNISolone Sodium Succ 100 mg IV ONCE Duration: 1 Doses
#    POD #3   Order date: [**9-27**] @ 1715 27. Sulfameth/Trimethoprim Suspension
#    10 ml PO/NG DAILY  Order date: [**9-27**] @ 1715
#    14. MethylPREDNISolone Sodium Succ 70 mg IV ONCE Duration: 1 Doses
#    POD #4  Order date: [**9-27**] @ 1715 28. ValGANCIclovir Suspension 450 mg
#    PO DAILY  Order date: [**9-27**] @ 1715
#    24 Hour Events:
#  OR RECEIVED - At [**2196-9-27**] 05:55 PM
#  ARTERIAL LINE - START [**2196-9-27**] 06:29 PM
#  CCO PAC - START [**2196-9-27**] 06:30 PM
#  EKG - At [**2196-9-27**] 06:36 PM
#    [**9-27**] OLT: OR - 5500 Cell [**Doctor Last Name **], 22 U PRBC, 44 FFP, 6 Plts, 1 Cryo, 3000
#    IVF, 450 UOP. Post-op: 3 Units PRBC
#    Post operative day:
#    POD#1 - liver transplant.
#    Allergies:
#    No Known Drug Allergies
#    Last dose of Antibiotics:
#    Bactrim (SMX/TMP) - [**2196-9-27**] 08:00 PM
#    Fluconazole - [**2196-9-27**] 08:00 PM
#    Ampicillin/Sulbactam (Unasyn) - [**2196-9-27**] 09:56 PM
#    Infusions:
#    Insulin - Regular - 4 units/hour
#    Other ICU medications:
#    Morphine Sulfate - [**2196-9-27**] 11:35 PM
#    Furosemide (Lasix) - [**2196-9-27**] 11:40 PM
#    Flowsheet Data as of  [**2196-9-28**] 05:53 AM
#    Vital signs
#    Hemodynamic monitoring
#    Fluid balance
#                                                                   24 hours
#                                                              Since [**99**] a.m.
#    Tmax: 37.6
# C (99.7
#    T current: 36.9
# C (98.4
#    HR: 91 (91 - 125) bpm
#    BP: 134/72(91) {119/66(85) - 161/79(101)} mmHg
#    RR: 0 (0 - 14) insp/min
#    SPO2: 100%
#    Heart rhythm: SR (Sinus Rhythm)
#    Wgt (current): 117.6 kg (admission): 119 kg
#    CVP: 5 (5 - 31) mmHg
#    PAP: (27 mmHg) / (13 mmHg)
#    CO/CI (CCO): (10.8 L/min) / ()
#    SvO2: 83%
#    Mixed Venous O2% sat: 82 - 82
#    Total In:
#                                                                  31,877 mL
#                                                                     334 mL
#    PO:
#    Tube feeding:
#    IV Fluid:
#                                                                     809 mL
#                                                                     334 mL
#    Blood products:
#                                                                  31,008 mL
#    Total out:
#                                                                  16,340 mL
#                                                                     383 mL
#    Urine:
#                                                                     185 mL
#                                                                      38 mL
#    NG:
#                                                                     150 mL
#    Stool:
#    Drains:
#                                                                     220 mL
#                                                                     195 mL
#    Balance:
#                                                                  15,537 mL
#                                                                     -49 mL
#    Respiratory support
#    O2 Delivery Device: Endotracheal tube
#    Ventilator mode: PRVC/AC
#    Vt (Set): 800 (800 - 850) mL
#    Vt (Spontaneous): 0 (0 - 0) mL
#    RR (Set): 14
#    RR (Spontaneous): 0
#    PEEP: 5 cmH2O
#    FiO2: 40%
#    PIP: 35 cmH2O
#    Plateau: 26 cmH2O
#    SPO2: 100%
#    ABG: 7.50/35/94.[**Numeric Identifier 299**]/28/3
#    Ve: 8.7 L/min
#    PaO2 / FiO2: 235
#    Physical Examination
#    General Appearance: No acute distress
#    Cardiovascular: (Rhythm: Regular), (Murmur: No(t) Systolic, No(t)
#    Diastolic)
#    Respiratory / Chest: (Expansion: Symmetric), (Breath Sounds:
#    Diminished: bases, b/l)
#    Abdominal: Soft, Distended, JPx2 Sang/Serosang. Serosang drainage from
#    chevron surgical incision
#    Left Extremities: (Edema: 4+), (Temperature: Warm)
#    Right Extremities: (Edema: 4+), (Temperature: Warm)
#    Neurologic: Sedated
#    Labs / Radiology
#    60 K/uL
#    10.2 g/dL
#    210 mg/dL
#    1.8 mg/dL
#    28 mEq/L
#    4.8 mEq/L
#    25 mg/dL
#    103 mEq/L
#    141 mEq/L
#    26.2 %
#    8.3 K/uL
#         [image002.jpg]
#                              [**2196-9-27**]  08:09 PM
#                              [**2196-9-27**]  09:33 PM
#                              [**2196-9-27**]  09:36 PM
#                              [**2196-9-27**]  11:17 PM
#                              [**2196-9-27**]  11:55 PM
#                              [**2196-9-28**]  12:00 AM
#                              [**2196-9-28**]  01:23 AM
#                              [**2196-9-28**]  02:39 AM
#                              [**2196-9-28**]  04:12 AM
#                              [**2196-9-28**]  04:26 AM
#    WBC
#    10.0
#    8.1
#    8.3
#    Hct
#    23
#    27.6
#    31
#    27.5
#    27.3
#    29
#    26.2
#    Plt
#    83
#    61
#    60
#    Creatinine
#    1.3
#    1.8
#    1.8
#    TCO2
#    25
#    29
#    25
#    30
#    30
#    28
#    Glucose
#    188
#    259
#    246
#    238
#    210
#    Other labs: PT / PTT / INR:14.3/33.8/1.2, ALT / AST:[**Telephone/Fax (1) 8899**], Alk-Phos
#    / T bili:88/8.4, Amylase / Lipase:34/, Fibrinogen:187 mg/dL, Lactic
#    Acid:2.5 mmol/L, Albumin:2.8 g/dL, Ca:10.3 mg/dL, Mg:1.8 mg/dL, PO4:5.3
#    mg/dL
#    Assessment and Plan
#    RENAL FAILURE, ACUTE (ACUTE RENAL FAILURE, ARF), RESPIRATORY FAILURE,
#    ACUTE (NOT ARDS/[**Doctor Last Name 76**]), TRANSPLANT, LIVER
#    Assessment and Plan: 45M c EtOh Cirrhosis now s/p OLT [**9-27**].
#    .
#    PLAN:
#    Neuro: wean Propofol Gtt for light Sedation, Morphine IV PRN Pain
#    CVS: Swan via R IJ, No pressors required Post-op, Hyperdynamic state
#    resolving. Will d/c CCO
#    Pulm: Intubated, wean to PS. as tolerated, massive fluid shifts
#    expected
#    GI: NPO, OGT to LCWS, Abdominal/Liver U/S in am [**9-28**] will repeat [**9-29**]
#    for R post Portal v flow
#    FEN: KVO
#    Renal: Foley, Cr 1.0 pre-op-> 1.3 post,
#    Heme: Goals HCT >30, Plts>50, Fibrinogen>150, INR<1.5, Transfuse PRBC,
#    Plts, FFP PRN
#    Endo: Insulin gtt, Methylprednisolone taper
#    ID: Unasyn x3 doses post-op, Valgan to x2/wk/Bactrim/Fluc for
#    Prophylaxis
#    Wounds/injuries: Chevron Abd surgical incision
#    Consults: Transplant
#    Code: Full
#    Disposition: SICU
#    Post-op Resp insufficiency
#    ICU Care
#    Nutrition:
#    Glycemic Control:  Insulin infusion
#    Lines: Swan to CVL today
#    Arterial Line - [**2196-9-27**] 06:29 PM
#    CCO PAC - [**2196-9-27**] 06:30 PM
#    RIC - [**2196-9-27**] 06:31 PM
#    16 Gauge - [**2196-9-27**] 06:33 PM
#    Prophylaxis:
#    DVT: Boots
#    Stress ulcer: PPI
#    Code status: Full code
#    Disposition: ICU
#    Total time spent: 31 min
#
#
#
#
# ================================================================================
# NOTE INDEX: 261
# colon_header_count         0
# uppercase_header_count     0
# numeric_token_count       18
# bp_pattern_count           2
# deid_token_count           2
# Name: 261, dtype: int64
# --------------------------------------------------------------------------------
# [**Wardname **] 4 ICU nursing progress note:
#  Altered Hemodynamics
#  S/O Remained hypotensive with poor u/o early in shift..started on vassopressin..neo dc'd..eventually levophed added with increase in bp..90-104/60. Swan-Ganz advanced by Pulmonary Fellow..repeat xray done..improved tracings..Increased IVF..200hr..PCW down to 10-12..co 5.9-5.5  By 6am..u/o has increased 30-40hr..much clearer..PCW slowly rising now 13-14..Pt was also digitilized..HR 80-90's..intitially in/out af with alot of PVCs...By [**2195**] in NSR....ectopy persists. Amioderone continues. Electrolytes wnl..??r/i for small MI by enzymes..
#  A. Needing volume and bp support
#  P. Continue to follow swan #s..u/o..hr/vea..??may need increased fluid boluses..
#  Pneumonia
#  S/O Continues intubated and vented..AC12/700/50% spontaneous rr 10=14..abgs good.Suctioned for copious amts tan/blood tinged sputum..
#  A. Bilateral pneumonia per cxr..Afebril
#  P. Pulmonary toilet..antibiotics..
#  Sedation
#  S/O Pt appearing uncomfortable..grimacing..moving legs off bed..Placed on fentanyl gtt and prn doses of ativan..increased fentanyl to 75mic/hr..pt still with some spontaneous moving..Wrist restraints on..
#  A. Responding well to increased doses of fentanyl and ativan
#  P. To keep comfortable..
#
#
#
#
#
# ================================================================================
# NOTE INDEX: 262
# colon_header_count         81
# uppercase_header_count     15
# numeric_token_count       122
# bp_pattern_count            6
# deid_token_count           12
# Name: 262, dtype: int64
# --------------------------------------------------------------------------------
# Chief Complaint:  Expressive aphasia
#    HPI:
#    History is taken per the patient who is a very poor historian.  He
#    reports that over the past two days he has been confused and has had
#    trouble thinking and speaking.  He cannot explain further. He is not
#    experiencing any pain.  No fevers or chills.  No chest pain or
#    difficulty breathing.  No nausea, vomiting, abdominal pain, diarrhea,
#    constipation, dysuria, hematuria, leg pain or swelling.  No focal
#    numbness or weakness.  No blurry vision or diplopia.  No lightheadeness
#    or dizziness  No gait instability.  No headache, photophobia or neck
#    stiffness.  He cannot explain the sensation further.  He presented to
#    [**Hospital3 **] hospital.
#    He initially presented to Cape Code hospital were his vital signs were
#    T: 97.7 BP: 97/62 HR: 92 RR: 16 O2: 100% on RA. Labs were notable for a
#    troponin of 0.01, BNP of 12.5, Tbili of 0.6, Na 133, K 4.0, Cl 97, Co2
#    27, BUN 10, Cr 0.98, Glu 100, INR 1.1, WBC 12.1, Hct 25, Plts 406.  He
#    had a CT of the head which showed a low attenuation zone in the
#    posterior corona radiate left extending along the left external capsule
#    of uncertain etiology.  MRI scan showed multiple acute/subacute
#    infracts with paramagnetic effect left temporal lobe and right parietal
#    hemisphere suggestive of hemosiderin from hemorrhage. He was
#    transferred to this hospital for further management.
#    In the ED, initial vs were: T: 98.8 P: 80 BP: 82/56 R: 20 O2 sat 98% on
#    RA. His initial EKG showed normal sinus rhythm at 83, leftward axis,
#    incomplete right bundle branch, TWI in V1, V2, no acute ST segment
#    changes, no priors for comparison.  Patient was given three liters of
#    normal saline, vancomycin 1 gram IV x 1, zosyn 4.5 g IV x 1.  He
#    develped a mild erythematous rash after receiving vancomycin and
#    received benadryl 50 mg IV x 1.
#    On arrival to the floor he has no specific complaints but says he feels
#    funny.  He is able to name common objects but is unable to say why he
#    is in the hospital.  He gets very agitated during interview.  Unable to
#    obtain further history.
#    Review of systems:
#    (+) Per HPI
#    (-) Denies fever, chills, night sweats, recent weight loss or gain.
#    Denies headache, sinus tenderness, rhinorrhea or congestion. Denied
#    cough, shortness of breath. Denied chest pain or tightness,
#    palpitations. Denied nausea, vomiting, diarrhea, constipation or
#    abdominal pain. No recent change in bowel or bladder habits. No
#    dysuria. Denied arthralgias or myalgias.
#    Patient admitted from: [**Hospital1 1**] ER
#    History obtained from [**Hospital 31**] Medical records
#    Allergies:
#    No Known Drug Allergies
#    Last dose of Antibiotics:
#    Ceftriaxone - [**2164-9-26**] 07:58 AM
#    Infusions:
#    Other ICU medications:
#    Heparin Sodium (Prophylaxis) - [**2164-9-26**] 05:53 AM
#    Other medications:
#    None
#    Past medical history:
#    Family history:
#    Social History:
#    Mitral valve prolapse
#    Endocardiits
#    Kidney Stones
#    Denies a family history of neurologic disease.
#    Occupation: Unemployed
#    Drugs: Remote history of using "all drugs you can name"
#    Tobacco: Denies
#    Alcohol:
#    Other: Lives with his girlfriend.
#    Review of systems:
#    Constitutional: No(t) Fever
#    Cardiovascular: No(t) Chest pain, No(t) Palpitations, No(t) Edema,
#    No(t) Tachycardia, No(t) Orthopnea
#    Nutritional Support: No(t) Tube feeds
#    Respiratory: No(t) Cough, No(t) Dyspnea, No(t) Tachypnea, No(t) Wheeze
#    Gastrointestinal: No(t) Abdominal pain, No(t) Nausea, No(t) Emesis,
#    No(t) Diarrhea, No(t) Constipation
#    Genitourinary: No(t) Dysuria, No(t) Foley, No(t) Dialysis
#    Musculoskeletal: No(t) Joint pain, No(t) Myalgias
#    Integumentary (skin): No(t) Rash
#    Endocrine: No(t) Hyperglycemia
#    Heme / Lymph: Anemia
#    Neurologic: No(t) Headache
#    Allergy / Immunology: Immunocompromised
#    Pain: No pain / appears comfortable
#    Flowsheet Data as of [**2164-9-26**] 08:08 AM
#    Vital Signs
#    Hemodynamic monitoring
#    Fluid Balance
#                                                                   24 hours
#                                                                Since 12 AM
#    Tmax: 37.3
# C (99.2
#    Tcurrent: 37.3
# C (99.2
#    HR: 94 (79 - 94) bpm
#    BP: 90/47(57) {90/47(57) - 99/59(68)} mmHg
#    RR: 16 (13 - 18) insp/min
#    SpO2: 97%
#    Heart rhythm: SR (Sinus Rhythm)
#    Wgt (current): 54 kg (admission): 54 kg
#              Total In:
#              2,060 mL
#    PO:
#              TF:
#    IVF:
#    260 mL
#    Blood products:
#    Total out:
#                                                                       0 mL
#                                                                     300 mL
#    Urine:
#    NG:
#    Stool:
#    Drains:
#    Balance:
#                                                                       0 mL
#                                                                   1,760 mL
#    Respiratory
#    O2 Delivery Device: None
#    SpO2: 97%
#    Physical Examination
#    Vitals: T: 99.2 BP: 99/59 P: 88 R: 13 O2: 97% on RA
#    General: Alert, oriented, no acute distress
#    HEENT: Sclera anicteric, MM dry, poor dentition
#    Neck: supple, JVP not elevated, no LAD
#    Lungs: Clear to auscultation bilaterally, no wheezes, rales, ronchi
#    CV: Regular rate and rhythm, normal S1 + S2, II/VI HSM at apex, no rubs
#    or gallops
#    Abdomen:  soft, non-tender, non-distended, bowel sounds present, no
#    rebound tenderness or guarding, no organomegaly
#    GU: no foley
#    Ext: warm, well perfused, 2+ pulses, no clubbing, cyanosis or edema
#    Neurologic: CN II-XII tested and intact, strength 5/5 in upper and
#    lower extremities bilterally, sensation intact to light touch and cold
#    bilaterally, is able to name simple objects, is able to repeat, finger
#    to nose intact, gait intact. Toes downgoing.
#    Skin: No splinter hemorrhages, no rashes, no osler nodes
#    Labs / Radiology
#         [image002.jpg]
#    Fluid analysis / Other labs: Troponin of 0.01, BNP of 12.5, Tbili of
#    0.6, Na 133, K 4.0, Cl 97, Co2 27, BUN 10, Cr 0.98, Glu 100, INR 1.1,
#    WBC 12.1, Hct 25, Plts 406.
#    Imaging: MRI/MRA Head w/o contrast [**2164-9-25**]: Multiple acute/subacute
#    infracts with paramagnetic effect left temporal lobe and rigth parietal
#    hemisphere suggestive of hemosiderin from hemorrhage.  Suggestion of
#    petechail hemorrhage was also noted on recent head CT.  The
#    multiplicity of infarcts is suggestive of embolic source. There is
#    gradual narrowing of the M2 segment of the left middle cerebral artery
#    with paucity of signal involving cistal branch vessels.  Findings are
#    consistent with hemodynamically significant stenosis and probable
#    distal occlusion  There is no evidence of aneurysm or high flow AVM.
#    Microbiology: blood and urine cultures pending
#    ECG: normal sinus rhythm at 83, leftward axis, incomplete right bundle
#    branch, TWI in V1, V2, no acute ST segment changes, no priors for
#    comparison.
#    Assessment and Plan
#  CVA (STROKE, CEREBRAL INFARCTIO
#    Assessment and Plan: 39 year old male with a history of mitral valve
#    endocarditis and IV drug use presenting with word finding difficulties
#    and new infarctions on brain MRI.
#    Word finding difficulties/Brain lesions:  Difficult for me to ilicit on
#    exam tonight as patient is non-cooperative but was described at [**Location (un) **] as an expressive aphasia.  He reports a remote history of
#    endocarditis and IV drug use although exam is notable for an apical
#    murmur and his toxicology screen is positive for cocaine and
#    barbituates. Concern that this may represent endocarditis with septic
#    embolic phenomenon. Cardiology is aware of case with plans for TEE in
#    AM.  Neurology is also consult and will see the patient in the ICU.
#    - NPO for TEE in AM
#    - cardiology consult
#    - neurology consult
#    - blood and urine cultures pending
#    - will cover with vancomycin and ceftriaxone empirically for
#    endocarditis pending blood cultures and TEE (will need to monitor
#    closely given concern for rash in ER)
#    - will need to obtain outside medical records
#    - consider ID consult
#    - HIV test in AM
#    Hypotension:  Patient with blood pressures in the 80s to 90s systolic.
#    Asymptomatic.  Not tachycardia.  Afebrile with normal WBC count.  Mild
#    anemia.  Blood pressures improved with IVF.  Concern that this may be
#    related to endocarditis/mitral valve disease.
#    - monitor blood pressures
#    - TEE
#    - guaiac stools, assess for blood loss
#    - blood cultures, urine cultures and antibiotics as above for potential
#    endocarditis
#    - will check cardiac enzymes given positive cocaine history
#    Anemia:  Unclear etiology.  Patient with mildly low blood pressures
#    which could be related to blood loss.
#    - guaiac stools
#    - iron studies
#    - trend hematocrit
#    Tobacco Use:
#    - nicotine patch
#    FEN: NS @ 100 cc/hr overnight, replete electrolytes, NPO for TEE in AM
#    Prophylaxis: Subutaneous heparin
#    Access: peripherals
#    Code:  Full
#    Communication: Patient, mother [**Name (NI) 2580**] [**Name (NI) 9254**] [**Telephone/Fax (1) 9255**]
#    Disposition: pending clinical improvementN), OTHER
#    ICU Care
#    Nutrition:
#    Glycemic Control:
#    Lines:
#    20 Gauge - [**2164-9-26**] 04:02 AM
#    Prophylaxis:
#    DVT: SQ UF Heparin
#    Stress ulcer: Not indicated
#    VAP:
#    Comments:
#    Communication: Patient discussed on interdisciplinary rounds , Family
#    meeting held , ICU consent signed Comments:
#    Code status: Full code
#    Disposition: ICU
#
#
#
#
# ================================================================================
# NOTE INDEX: 141
# colon_header_count        0
# uppercase_header_count    0
# numeric_token_count       0
# bp_pattern_count          0
# deid_token_count          0
# Name: 141, dtype: int64
# --------------------------------------------------------------------------------
# pt remained on IMV through majority of PM. Plan is to extubate in early AM. She vommited aroud ETT twice during PM.
#
#
#
#
# ================================================================================
# NOTE INDEX: 144
# colon_header_count         79
# uppercase_header_count     20
# numeric_token_count       302
# bp_pattern_count            5
# deid_token_count           35
# Name: 144, dtype: int64
# --------------------------------------------------------------------------------
# TITLE: Intensivist Note -- Surgical Critical Care
#    CVICU
#    HPI:
#    HD3   POD 1-CABG x2(LIMA-LAD, SVG-OM)
#    Ejection Fraction:55
#    Hempglobin A1c:5.8
#    Pre-Op Weight:175 lbs   79.38 kgs
#    Baseline Creatinine:1.1
#    PMH: Hyperlipidemia, Hypertension, Renal stone, Coronary artery disease
#    s/p Stent LAD
#    [**Last Name (un) **]: HCTZ 25', Lisinopril 10', Atenolol 50', ASA 81', Lipitor 80',
#    Bupropion XL 300', Diazepam [**4-17**] prn sleep
#    Plan:63yo man s/p CABG x2(LIMA-LAD,SVG-OM)[**7-28**]
#    Current medications:
#    Acetaminophen 5. Albuterol-Ipratropium 6. Aspirin EC 7. Atorvastatin
#    8. Calcium Gluconate 9. Dextrose 50% 10. Docusate Sodium 11. Insulin
#    12. Ketorolac
#    14. Magnesium Sulfate 15. Metoclopramide 16. Milk of Magnesia 17.
#    Oxycodone-Acetaminophen 18. Oxycodone-Acetaminophen
#    19. Phenylephrine 20. Potassium Chloride 21. Ranitidine 22. Sodium
#    Chloride 0.9% Flush 23. Sodium Chloride 0.9% Flush
#    24. Vancomycin
#    24 Hour Events:
#  ARTERIAL LINE - START [**2168-7-28**] 01:33 PM
#  OR RECEIVED - At [**2168-7-28**] 01:34 PM
#  INVASIVE VENTILATION - START [**2168-7-28**] 01:34 PM
#  CORDIS/INTRODUCER - START [**2168-7-28**] 01:44 PM
#  PA CATHETER - START [**2168-7-28**] 01:44 PM
#  NASAL SWAB - At [**2168-7-28**] 01:55 PM
#  EKG - At [**2168-7-28**] 02:13 PM
#  EXTUBATION - At [**2168-7-29**] 06:45 AM
#  FEVER - 101.1
# C - [**2168-7-29**] 12:00 AM
#    Post operative day:
#    HD3 POD#1 s/p CABG x2(LIMA-LAD,SVG-OM)[**7-28**], EF 55%
#    Allergies:
#    No Known Drug Allergies
#    Last dose of Antibiotics:
#    Vancomycin - [**2168-7-28**] 07:56 PM
#    Infusions:
#    Phenylephrine - 1 mcg/Kg/min
#    Other ICU medications:
#    Ranitidine (Prophylaxis) - [**2168-7-28**] 02:31 PM
#    Insulin - Regular - [**2168-7-28**] 10:09 PM
#    Morphine Sulfate - [**2168-7-29**] 07:51 AM
#    Other medications:
#    Flowsheet Data as of  [**2168-7-29**] 09:25 AM
#    Vital signs
#    Hemodynamic monitoring
#    Fluid balance
#                                                                   24 hours
#                                                              Since [**70**] a.m.
#    Tmax: 38.4
# C (101.1
#    T current: 37.3
# C (99.1
#    HR: 84 (66 - 97) bpm
#    BP: 98/60(69) {78/46(58) - 196/105(141)} mmHg
#    RR: 21 (8 - 27) insp/min
#    SPO2: 96%
#    Heart rhythm: SR (Sinus Rhythm)
#    Wgt (current): 93.8 kg (admission): 79.3 kg
#    Height: 65 Inch
#    CVP: 7 (1 - 23) mmHg
#    PAP: (32 mmHg) / (12 mmHg)
#    CO/CI (Thermodilution): () / (2.2 L/min/m2)
#    SVR: 1,030 dynes*sec/cm5
#    SV: 53 mL
#    SVI: 28 mL/m2
#    Total In:
#                                                                   6,597 mL
#                                                                   1,631 mL
#    PO:
#    Tube feeding:
#    IV Fluid:
#                                                                   6,097 mL
#                                                                   1,631 mL
#    Blood products:
#                                                                     500 mL
#    Total out:
#                                                                   1,580 mL
#                                                                   1,225 mL
#    Urine:
#                                                                     685 mL
#                                                                     955 mL
#    NG:
#    Stool:
#    Drains:
#                                                                      45 mL
#    Balance:
#                                                                   5,017 mL
#                                                                     406 mL
#    Respiratory support
#    O2 Delivery Device: Endotracheal tube
#    Ventilator mode: CMV/ASSIST/AutoFlow
#    Vt (Set): 550 (550 - 550) mL
#    PS : 5 cmH2O
#    RR (Set): 13
#    RR (Spontaneous): 0
#    PEEP: 5 cmH2O
#    FiO2: 40%
#    RSBI: 61
#    PIP: 23 cmH2O
#    Plateau: 15 cmH2O
#    SPO2: 96%
#    ABG: 7.39/42/132/26/0
#    Ve: 7.8 L/min
#    PaO2 / FiO2: 330
#    Physical Examination
#    General Appearance: No acute distress
#    HEENT: PERRL, EOMI
#    Cardiovascular: (Rhythm: Regular)
#    Respiratory / Chest: (Expansion: Symmetric), (Breath Sounds:
#    Diminished: (B)), (Sternum: Stable )
#    Abdominal: Soft, Non-distended, Non-tender, hypoactive
#    Left Extremities: (Edema: Trace), (Temperature: Warm), (Pulse -
#    Dorsalis pedis: Present)
#    Right Extremities: (Edema: Trace), (Temperature: Cool), (Pulse -
#    Dorsalis pedis: Present)
#    Skin: (Incision: Clean / Dry / Intact)
#    Neurologic: (Awake / Alert / Oriented: x 3), Follows simple commands,
#    (Responds to: Verbal stimuli), Moves all extremities
#    Labs / Radiology
#    239 K/uL
#    9.0 g/dL
#    114
#    1.0 mg/dL
#    26 mEq/L
#    4.2 mEq/L
#    15 mg/dL
#    109 mEq/L
#    139 mEq/L
#    26.4 %
#    8.9 K/uL
#                              [**2168-7-29**]  01:00 AM
#                              [**2168-7-29**]  01:46 AM
#                              [**2168-7-29**]  01:51 AM
#                              [**2168-7-29**]  02:00 AM
#                              [**2168-7-29**]  03:00 AM
#                              [**2168-7-29**]  04:00 AM
#                              [**2168-7-29**]  04:10 AM
#                              [**2168-7-29**]  06:00 AM
#                              [**2168-7-29**]  06:37 AM
#                              [**2168-7-29**]  08:00 AM
#    WBC
#    8.9
#    Hct
#    26.4
#    Plt
#    239
#    Creatinine
#    1.0
#    TCO2
#    22
#    25
#    26
#    Glucose
#    96
#    92
#    80
#    103
#    102
#    114
#    Other labs: PT / PTT / INR:14.0/38.1/1.2, Fibrinogen:117 mg/dL, Lactic
#    Acid:1.8 mmol/L, Mg:1.8 mg/dL, PO4:2.6 mg/dL
#    Assessment and Plan
#    PAIN CONTROL (ACUTE PAIN, CHRONIC PAIN), CORONARY ARTERY BYPASS GRAFT
#    (CABG)
#    Assessment and Plan: HD3 POD#1 s/p CABG x2(LIMA-LAD,SVG-OM)[**7-28**], EF
#    55%  HD stable, weaning off Neo, TX 1uPRBC for BP support-HCT=26
#    Neurologic: Neuro checks Q: 4 hr, Torodol/PCT prn pain.
#    Cardiovascular: Aspirin, Statins, Discontinue PA monitor, Wean off
#    Neo->HD stable, SR, Plan to start B-Blocker with no pressor
#    requirement. Cont ASA,Statin DC PA cath
#    Pulmonary: IS, Extubate today, Encourage DB&C,IS,OOB. CTs remain in due
#    to drg
#    Gastrointestinal / Abdomen: no issues
#    Nutrition: Advance diet as tolerated , ADAT, Cont prophylaxis, bowel
#    regiment
#    Renal: Foley, Adequate UO, BUN/Cr= 15/1. Stable, adequate uo.
#    Hematology: HCT= 26.4, PLTs stable=239, Tx 1uPRBC to optimize BP
#    Endocrine: Insulin drip, Insulin gtt
#    Infectious Disease: Check cultures, periop ABX
#    Lines / Tubes / Drains: Foley, Chest tube - pleural , Chest tube -
#    mediastinal, Pacing wires
#    Wounds: Dry dressings
#    Imaging:
#    Fluids:  LR bolus O/N minimize to 1000cc/24h
#    Consults: CT surgery, P.T.
#    ICU Care
#    Nutrition:
#    Glycemic Control:  Regular insulin sliding scale, Insulin infusion
#    Lines:
#    Arterial Line - [**2168-7-28**] 01:33 PM
#    Cordis/Introducer - [**2168-7-28**] 01:44 PM
#    PA Catheter - [**2168-7-28**] 01:44 PM
#    20 Gauge - [**2168-7-29**] 08:44 AM
#    Prophylaxis:
#    DVT:
#    Stress ulcer: H2 blocker
#    Communication: Patient discussed on interdisciplinary rounds , ICU
#    Code status: Full code
#    Disposition: [**Hospital 1025**] Transfer to floor                       Dx  Post-op
#    Resp insufficiency
#
#
#
#
# ================================================================================
# NOTE INDEX: 146
# colon_header_count        8
# uppercase_header_count    0
# numeric_token_count       0
# bp_pattern_count          0
# deid_token_count          0
# Name: 146, dtype: int64
# --------------------------------------------------------------------------------
# .H/O renal failure, End stage (End stage renal disease, ESRD)
#    Assessment:
#    Action:
#    Response:
#    Plan:
#    Tracheobronchomalacia (tracheomalacia, bronchomalacia)
#    Assessment:
#    Action:
#    Response:
#    Plan:
#
#
#
#
# ================================================================================
# NOTE INDEX: 149
# colon_header_count         75
# uppercase_header_count     21
# numeric_token_count       299
# bp_pattern_count            4
# deid_token_count           37
# Name: 149, dtype: int64
# --------------------------------------------------------------------------------
# CVICU
#    HPI:
#    [**7-29**] POD 1
#    s/p Asc Aorta and hemi arch replacement (28mm gelweave graft) [**7-28**]
#    EF: Cr: 0.8 Wt: HgA1c: none
#    PMHx:
#    PMH: Asc aortic aneurysm, AI, rt breast CA [**2120**], recurrence in lymph
#    node [**2121**], hyperlipidemia, meningitis vs. viral encephalitis at age 25,
#    PMR x 2, polio at age 16 - mild muscle weakness, GERD, bilateral
#    peripheral neuropathy, Depression, Right breast lumpectomy [**2120**], Left
#    lumpectomy - benign, Right knee arthroscopy
#    [**Last Name (un) **]: Atenolol 12.5mg qd, Zetia 10mg qd, Letrozole 2.5mg qd, Loazepam
#    1mg ([**2-7**]) qd prn, Trastuzumab q3wks, Effexor XR 75mg qd, Aspirin 81mg
#    qd, MVI, Folic acid qd, Aciphex, Citrucell qd, Calcium carbonate-Vit D3
#    500-200mg [**Hospital1 **]
#    Current medications:
#    Acetaminophen 4. Aspirin EC 5. Aspirin 6. Calcium Gluconate 7.
#    CefazoLIN 8. Chlorhexidine Gluconate 0.12% Oral Rinse 9. Dextrose 50%
#    10. Docusate Sodium 11. Docusate Sodium (Liquid) 12. Furosemide 13.
#    Glycopyrrolate 14. Insulin 15. Letrozole 16. Magnesium Sulfate 17.
#    Metoprolol Tartrate 18. Metoprolol Tartrate 19. Metoprolol Tartrate 20.
#    Metoclopramide 21. Milk of Magnesia 22. Morphine Sulfate 23.
#    Neostigmine 24. Nitroglycerin 25. Ondansetron 26.
#    Oxycodone-Acetaminophen 27. Phenylephrine 28. Pneumococcal Vac
#    Polyvalent 29. Potassium Ranitidine  Venlafaxine XR
#    24 Hour Events:
#  CORDIS/INTRODUCER - START [**2127-7-28**] 12:45 PM
#  PA CATHETER - START [**2127-7-28**] 12:45 PM
#  OR RECEIVED - At [**2127-7-28**] 12:45 PM
#  ARTERIAL LINE - START [**2127-7-28**] 12:45 PM
#  INVASIVE VENTILATION - START [**2127-7-28**] 12:45 PM
#  EKG - At [**2127-7-28**] 04:07 PM
#  CORDIS/INTRODUCER - STOP [**2127-7-29**] 06:00 AM
#  PA CATHETER - STOP [**2127-7-29**] 06:03 AM
#  EXTUBATION - At [**2127-7-29**] 06:40 AM
#    Post operative day:
#    [**7-29**] POD 1
#    s/p Asc Aorta and hemi arch replacement (28mm gelweave graft) [**7-28**]
#    Allergies:
#    Remeron (Oral) (Mirtazapine)
#    asthma;
#    Infusions:
#    Insulin - Regular - 2 units/hour
#    Other ICU medications:
#    Morphine Sulfate - [**2127-7-28**] 11:15 PM
#    Metoprolol - [**2127-7-29**] 01:38 AM
#    Flowsheet Data as of  [**2127-7-29**] 10:02 AM
#    Vital signs
#    Hemodynamic monitoring
#    Fluid balance
#                                                                   24 hours
#                                                              Since [**30**] a.m.
#    Tmax: 36.9
# C (98.4
#    T current: 36.3
# C (97.3
#    HR: 75 (62 - 95) bpm
#    BP: 102/57(76) {86/53(66) - 158/100(121)} mmHg
#    RR: 17 (6 - 21) insp/min
#    SPO2: 97%
#    Heart rhythm: SR (Sinus Rhythm)
#    Height: 66 Inch
#    CVP: 8 (1 - 17) mmHg
#    PAP: (25 mmHg) / (12 mmHg)
#    PCWP: 10 (10 - 10) mmHg
#    CO/CI (Thermodilution): (3.77 L/min) / (2.3 L/min/m2)
#    CO/CI (Fick): (5.2 L/min) / (3.2 L/min/m2)
#    SVR: 1,613 dynes*sec/cm5
#    Mixed Venous O2% sat: 71 - 77
#    SV: 52 mL
#    SVI: 32 mL/m2
#    Total In:
#                                                                   9,959 mL
#                                                                     517 mL
#    PO:
#    Tube feeding:
#    IV Fluid:
#                                                                   7,619 mL
#                                                                     517 mL
#    Blood products:
#                                                                   2,340 mL
#    Total out:
#                                                                   1,940 mL
#                                                                   1,140 mL
#    Urine:
#                                                                   1,570 mL
#                                                                     970 mL
#    NG:
#    Stool:
#    Drains:
#    Balance:
#                                                                   8,019 mL
#                                                                    -623 mL
#    Respiratory support
#    O2 Delivery Device: Nasal cannula
#    Ventilator mode: CPAP/PSV
#    Vt (Set): 450 (450 - 590) mL
#    Vt (Spontaneous): 485 (309 - 1,184) mL
#    PS : 5 cmH2O
#    RR (Set): 12
#    RR (Spontaneous): 0
#    PEEP: 5 cmH2O
#    FiO2: 70%
#    RSBI: 98
#    PIP: 20 cmH2O
#    Plateau: 16 cmH2O
#    SPO2: 97%
#    ABG: 7.36/42/78.[**Numeric Identifier 7**]/22/-1
#    Ve: 6.1 L/min
#    PaO2 / FiO2: 197
#    Physical Examination
#    General Appearance: No acute distress, Well nourished
#    HEENT: PERRL
#    Cardiovascular: (Rhythm: Regular)
#    Respiratory / Chest: (Expansion: Symmetric), (Breath Sounds: CTA
#    bilateral : ), (Sternum: Stable )
#    Abdominal: Soft, Non-tender, No(t) Bowel sounds present
#    Left Extremities: (Edema: Absent), (Temperature: Cool), (Pulse -
#    Dorsalis pedis: Diminished), (Pulse - Posterior tibial: Diminished)
#    Right Extremities: (Edema: Absent), (Temperature: Cool), (Pulse -
#    Dorsalis pedis: Diminished), (Pulse - Posterior tibial: Diminished)
#    Skin: (Incision: Clean / Dry / Intact)
#    Neurologic: (Awake / Alert / Oriented: x 3), Follows simple commands,
#    (Responds to: Verbal stimuli), Moves all extremities
#    Labs / Radiology
#    260 K/uL
#    11.7 g/dL
#    95
#    0.6 mg/dL
#    22 mEq/L
#    3.7 mEq/L
#    9 mg/dL
#    104 mEq/L
#    134 mEq/L
#    33.1 %
#    11.8 K/uL
#         [image002.jpg]
#                              [**2127-7-28**]  11:43 PM
#                              [**2127-7-29**]  01:54 AM
#                              [**2127-7-29**]  02:00 AM
#                              [**2127-7-29**]  02:02 AM
#                              [**2127-7-29**]  03:00 AM
#                              [**2127-7-29**]  04:00 AM
#                              [**2127-7-29**]  05:00 AM
#                              [**2127-7-29**]  05:37 AM
#                              [**2127-7-29**]  06:00 AM
#                              [**2127-7-29**]  06:25 AM
#    WBC
#    11.8
#    Hct
#    33.1
#    Plt
#    260
#    Creatinine
#    0.6
#    TCO2
#    21
#    23
#    26
#    25
#    Glucose
#    141
#    161
#    137
#    107
#    99
#    83
#    95
#    Other labs: PT / PTT / INR:12.3/25.3/1.0, Fibrinogen:123 mg/dL, Lactic
#    Acid:2.4 mmol/L, Ca:8.9 mg/dL, Mg:2.0 mg/dL
#    Assessment and Plan
#    AORTIC ANEURYSM, THORACIC (TAA)
#    Assessment and Plan: 70 yo woman s/p Asc aorta and hemirch replaceemnt
#    doing well post-operatively. c/o nausea
#    Neurologic: Pain controlled, Morphine for pain control hold percocet
#    given nausea, will add toradol
#    Cardiovascular: Aspirin, Beta-blocker, Discontinue PA monitor
#    Pulmonary: IS, extubated this AM
#    Gastrointestinal / Abdomen:
#    Nutrition: NPO, NPO until nausea improved
#    Renal: Foley, start diuretics to make net negative 1-1.5 liters today
#    Hematology: stable hct
#    Endocrine: RISS
#    Infectious Disease: no active issues
#    afebrile, normal wbc
#    Lines / Tubes / Drains: Foley, Chest tube - pleural , Chest tube -
#    mediastinal, Pacing wires
#    Wounds: Dry dressings
#    Imaging: CXR today, after ct removal
#    Consults: CT surgery
#    ICU Care
#    Nutrition: NPO until nausea resolves
#    Glycemic Control:  Regular insulin sliding scale
#    Lines:
#    Arterial Line - [**2127-7-28**] 12:45 PM
#    16 Gauge - [**2127-7-28**] 12:45 PM
#    18 Gauge - [**2127-7-28**] 12:45 PM
#    Prophylaxis:
#    DVT:
#    Stress ulcer: H2 blocker
#    VAP bundle: HOB elevation, Mouth care
#    Communication: Patient discussed on interdisciplinary rounds , ICU
#    Code status: Full code
#    Disposition: Transfer to floor
#
#
#
#
# ================================================================================
# NOTE INDEX: 150
# colon_header_count        0
# uppercase_header_count    0
# numeric_token_count       0
# bp_pattern_count          0
# deid_token_count          2
# Name: 150, dtype: int64
# --------------------------------------------------------------------------------
# RESPIRATORY CARE NOTE
#
# Patient received from floors intubated and placed on AC ventilation here in unit.  To OR for procedure.  Back in unit increased Peep d/t low PaO2.  Slowly decreasing FiO2.  BLBS are somewhat coarse and diminished.  Sxn for thick yellow secretions.
#
#                           [**First Name11 (Name Pattern1) **] [**Last Name (NamePattern4) **], RRT
#
#
#
#
# ================================================================================
# NOTE INDEX: 409
# colon_header_count        0
# uppercase_header_count    0
# numeric_token_count       8
# bp_pattern_count          0
# deid_token_count          3
# Name: 409, dtype: int64
# --------------------------------------------------------------------------------
# [**2103-7-15**] 1500
#      PT TO N/SICU FROM OR FOR I/D OF SCOTUM AND SUPRA PUBIC PLACEMENT SECONDARY SJS AND R/O NEC FAS PELVIS AREA ARRIVED STABLE SEDATED PROPOFOL ETT AIRWAY PATENT [**Hospital1 **] LAT B/S
#      NEURO MAE SPONT WILL TRY TO OPEN EYES TO COMAND PERL 2 [**Hospital1 **] LAT
#      RESP CMV WEANING CLEAR SPUTUM RHONCHI CLEARS AFTER SUCTIONING
#      HEART NSR S1S2 PR .16 QRS .08 QTC WNL FOR RATE AND AGE PULSES POS 3 THRU OUT
#      GI SUPRAPUBIC CLEAR DRAINAGE PELVIC DRESSING IN PLACE POS B/S HYPOACTIVE IN NATURE
#      PLAN SUPPORTIVE IN NATURE MONITOR AM REMOVAL OF ETT TUBE
#
#
#
#
# ================================================================================
# NOTE INDEX: 155
# colon_header_count        0
# uppercase_header_count    0
# numeric_token_count       0
# bp_pattern_count          0
# deid_token_count          0
# Name: 155, dtype: int64
# --------------------------------------------------------------------------------
# Respiratory Care
# Pt remains intubated, with only vent setting changes made to accomodate ABGt results showing hyperoxygention.  Pt has course bilateral lung sounds with diminished lung sounds at the lower lobes.  Pt was suctioned for copious amounts of arterial blood from ETT.  No acute respiratory issues this shift.  Pt remains on current support.
#
#
#
#
# ================================================================================
# NOTE INDEX: 158
# colon_header_count         78
# uppercase_header_count     17
# numeric_token_count       305
# bp_pattern_count            5
# deid_token_count           31
# Name: 158, dtype: int64
# --------------------------------------------------------------------------------
# CVICU
#    HPI:
#    72M s/p CABG x 5 (Lima-LAD, SVG-Diag, SVG-OM, SVG-Pda with Y-graft to
#    PLV) now POD 1
#    PMHx:
#    Wt 124K  Cr 0.9 HgbA1C 6.1 EF >55%
#    PMHx: HTN, Hyperlipidemia, Sciatica, Seasonal allergies, Elevated PSA,
#    negative biopsies per PCP note
#    [**Name9 (PRE) **]: Labetolol 200", Pravastatin 40', ASA 81', Claratin, Proscar 5',
#    Omeprazole 20', Saw pawmeto, calcium, mvi, selenium
#    Current medications:
#    1. 2. 250 mL D5W 3. Acetaminophen 4. Aspirin EC 5. Calcium Gluconate 6.
#    Dextrose 50% 7. Docusate Sodium 8. Finasteride 9. Furosemide 10.
#    HYDROmorphone (Dilaudid) 11. Insulin 12. Magnesium Sulfate 13.
#    Metoclopramide 14. Metoprolol Tartrate 15. Milk of Magnesia 16.
#    Nitroglycerin 17. Omeprazole 18. Oxycodone-Acetaminophen 19.
#    Phenylephrine 20. Potassium Chloride 21. Pravastatin 22. Sodium
#    Chloride 0.9% Flush 23. Vancomycin
#    24 Hour Events:
#  NASAL SWAB - At [**2114-5-7**] 01:08 PM
#  OR RECEIVED - At [**2114-5-7**] 01:08 PM
#  INVASIVE VENTILATION - START [**2114-5-7**] 01:09 PM
#  EKG - At [**2114-5-7**] 01:38 PM
#  ARTERIAL LINE - START [**2114-5-7**] 02:03 PM
#  PA CATHETER - START [**2114-5-7**] 02:03 PM
#  CORDIS/INTRODUCER - START [**2114-5-7**] 02:04 PM
#  INVASIVE VENTILATION - STOP [**2114-5-7**] 02:49 PM
#  EXTUBATION - At [**2114-5-7**] 06:54 PM
#    - Had pain overnight, started on SQ Dilaudid in addition to percocet
#    - Concern for sleep apnea, needs Sleep Study
#    - HD stable o/n
#    Allergies:
#    Penicillins
#    Unknown;
#    Iodine Containing Agents Classifier
#    Rash;
#    Last dose of Antibiotics:
#    Vancomycin - [**2114-5-8**] 07:50 AM
#    Infusions:
#    Insulin - Regular - 3 units/hour
#    Nitroglycerin - 0.5 mcg/Kg/min
#    Other ICU medications:
#    Morphine Sulfate - [**2114-5-7**] 07:32 PM
#    Insulin - Regular - [**2114-5-8**] 04:30 AM
#    Furosemide (Lasix) - [**2114-5-8**] 06:00 AM
#    Flowsheet Data as of  [**2114-5-8**] 08:14 AM
#    Vital signs
#    Hemodynamic monitoring
#    Fluid balance
#                                                                   24 hours
#                                                              Since [**16**] a.m.
#    Tmax: 37.5
# C (99.5
#    T current: 37.2
# C (99
#    HR: 81 (59 - 96) bpm
#    BP: 118/47(62) {74/39(52) - 164/93(138)} mmHg
#    RR: 24 (12 - 28) insp/min
#    SPO2: 95%
#    Heart rhythm: SR (Sinus Rhythm)
#    Height: 66 Inch
#    CVP: 3 (3 - 22) mmHg
#    PAP: (26 mmHg) / (15 mmHg)
#    CO/CI (Thermodilution): (7.32 L/min) / (3.1 L/min/m2)
#    SVR: 666 dynes*sec/cm5
#    SV: 84 mL
#    SVI: 37 mL/m2
#    Total In:
#                                                                   4,982 mL
#                                                                     537 mL
#    PO:
#                                                                      90 mL
#                                                                     120 mL
#    Tube feeding:
#    IV Fluid:
#                                                                   4,892 mL
#                                                                     417 mL
#    Blood products:
#    Total out:
#                                                                   2,375 mL
#                                                                   1,030 mL
#    Urine:
#                                                                   2,045 mL
#                                                                     780 mL
#    NG:
#                                                                      50 mL
#    Stool:
#    Drains:
#    Balance:
#                                                                   2,607 mL
#                                                                    -493 mL
#    Respiratory support
#    O2 Delivery Device: Nasal cannula
#    Ventilator mode: CPAP/PSV
#    Vt (Set): 770 (770 - 770) mL
#    PS : 5 cmH2O
#    RR (Set): 12
#    RR (Spontaneous): 0
#    PEEP: 5 cmH2O
#    FiO2: 50%
#    PIP: 36 cmH2O
#    Plateau: 17 cmH2O
#    SPO2: 95%
#    ABG: 7.41/37/134/25/-2
#    Ve: 11 L/min
#    PaO2 / FiO2: 268
#    Physical Examination
#    General Appearance: No acute distress
#    HEENT: PERRL
#    Cardiovascular: (Rhythm: Regular)
#    Respiratory / Chest: (Expansion: Symmetric), (Breath Sounds: CTA
#    bilateral : ), (Sternum: Stable )
#    Abdominal: Soft, Non-distended, Non-tender, Bowel sounds present
# ...
#    elevated, so he got a RUQ ultrasound which showed no cholecystitis.
#    .
#    Review of sytems:
#    (+) Per HPI
#    (-) Denies fever, chills, night sweats. Denies headache, sinus
#    tenderness, rhinorrhea or congestion. Denied cough, shortness of
#    breath. Denied chest pain or tightness, palpitations. Denied
#    constipation or abdominal pain.  No dysuria. Denied arthralgias or
#    myalgias.
#    Patient admitted from: [**Hospital1 54**] ER
#    History obtained from [**Hospital 85**] Medical records
#    Allergies:
#    No Known Drug Allergies
#    Last dose of Antibiotics:
#    Infusions:
#    Other ICU medications:
#    Other medications:
#    1. Nystatin PO QID PRN
#    2. Hydroxyzine HCl 25 mg QID
#    3. Oxycodone 5 mg PO Q6H
#    4.  Lidocaine 5 % patch
#    5.  Nitroglycerin 0.2 mg/hr Patch 24
#    6.  Lorazepam 0.5 -1 mg prn anxiety
#    7. Roxanol Concentrate prn pain
#    8. Methadone 40 mg q8 hours
#    9. Camphor-Menthol 0.5-0.5 % Lotion prn
#    10. Erythromycin 5 mg/g Ointment 1 inch Ophthalmic QID
#    11. Omeprazole 20 mg daily
#    12. Trimethoprim-Sulfamethoxazole 160-800 mg q HD
#    13. Captopril 50 mg TID
#    14. Acetaminophen 650 mg prn pain
#    15. Sevelamer HCl 800 mg PO TID with meals
#    16. Hydralazine 25 mg PO TID
#    17. Amlodipine 10 mg daily
#    Past medical history:
#    Family history:
#    Social History:
#    1.  HIV/AIDS, CD4 count of 5 in [**1-26**].  Not on HARRT.
#    2.  H/o coag negative staph endocardiits s/p MVR and AVR in [**1-25**], s/p
#    vanc x 4 weeks.  Then developed strep viridans endocarditis with
#    dehiscence of aortic valve, managed medically with vanc/gent.  External
#    pacemaker placed [**8-25**] due to 1st degree AV block, but was removed in
#    [**10-25**] due to pocket infection.
#    3.  H/o HCV + but has no detectable circulating virus
#    4.  HBV + but HBc equivocal [**10/2186**]
#    5.  ESRD secondary to HIV nephropathy on HD with LUE fistula
#    6.  Secondary hyperparathyroidism secondary to ESRD
#    7.  Chronic LBP reportedly to OA & nerve impingement
#    8.  Asthma
#    Was reportedly infected with HIV through sexual contact. Lives with his
#    mother.  [**Name (NI) 317**] smoked 1 ppd for 20 years, currently smoking 6
#    ciggarettes/day.  H/o of IVDU as teenager, but currently denies IVDU.
#    .
#    Family History:
#    Father with hypertension and diabetes mellitus
#    .
#    Occupation:
#    Drugs:
#    Tobacco:
#    Alcohol:
#    Other:
#    Review of systems:
#    Flowsheet Data as of [**2189-2-24**] 02:41 PM
#    Vital Signs
#    Hemodynamic monitoring
#    Fluid Balance
#                                                                   24 hours
#                                                                Since 12 AM
#    Tmax: 36.8
# C (98.3
#    Tcurrent: 36.8
# C (98.3
#    HR: 95 (95 - 97) bpm
#    BP: 104/70(77) {101/70(77) - 108/74(82)} mmHg
#    RR: 17 (14 - 17) insp/min
#    SpO2: 100%
#    Heart rhythm: SR (Sinus Rhythm)
#              Total In:
#              233 mL
#    PO:
#              TF:
#    IVF:
#    233 mL
#    Blood products:
#    Total out:
#                                                                       0 mL
#                                                                       0 mL
#    Urine:
#    NG:
#    Stool:
#    Drains:
#    Balance:
#                                                                       0 mL
#                                                                     233 mL
#    Respiratory
#    O2 Delivery Device: Nasal cannula
#    SpO2: 100%
#    Physical Examination
#    Vitals: BP 104/70, HR 95, RR 19, 100% on 3LNC
#    General: cachectic, somnolent
#    HEENT: Sclera icteric, dry mucous membranes with evidence of thrush and
#    oral ulcers,
#    Neck: supple, elevated JVP
#    Lungs: diminished breath sounds at right base, otherwise clear
#    CV: Regular rate and rhythm, systolic murmur at apex and at base
#    Abdomen:  mild tenderness diffusely, guarding, no rebound, unable to
#    assess for hepatosplenomegaly
#    Ext: b/l LE swelling with pitting edema to knees, cool hands and
#    feets.  Dopplerable LLE pulse.  LLE calf with erythema and tendernss.
#    Darkness of skin in hands and toes.
#    Labs / Radiology
#         [image002.jpg]
#    Other labs: Lactic Acid:3.8 mmol/L
#    Fluid analysis / Other labs:
#    137 | 92 | 69 /
#    -------------- 166
#    4.8 | 25 | 5.8 \
#    .
#    Ca 9.4
#    Mg 2.6
#    Phos 6.1
#    .
#    .. \ 14.4 /
#    4.7 ------ 35
#    .. / 44.7 \
#    .
#    Diff: 58%N, 5%Bands, 12%L, 25%M, 47%NRBCs
#    .
#    Lactate 5.7
#    .
#    PT 29.3
#    PTT  33.5
#    INR 3.0
#    .
#    Micro:
#    Blood cultures x 2 - pending
#    .
#    Images:
#    CXR - [**2189-2-24**] - RLL collapse and effusion
#    RUQ ultrasound - No acute cholecystitis.
#    .
#    EKG.
#    [**2189-2-24**] at 7:43 AM.  EK shows NSR at 96 npm.  PR interval of 192.  QRS
#    of 110 with LBBB morphology.  TWI in II, III, F, V4-V6.  q waves in II,
#    III, F, V5-V6.  LVH.  Right axis deviation.
#    .
#    Echo:  [**2188-10-24**].
#    The left atrium is dilated. A left-to-right shunt across a stretched
#    patent foramen ovale is seen at rest. There is moderate symmetric left
#    ventricular hypertrophy. The left ventricular cavity size is normal.
#    Regional left ventricular wall motion is normal. There is mild global
#    left ventricular hypokinesis (LVEF = 40-50%). The right ventricular
#    free wall is hypertrophied. Right ventricular chamber size is normal
#    with mild global free wall hypokinesis. A bioprosthetic aortic valve
#    prosthesis is present. The aortic valve prosthesis leaflets appear to
#    move normally, the transaortic gradient is normal for this prosthesis,
#    and there is no aortic regurgiation. However, motion of the aortic
#    annulus is abnormal. This could be related to complex surgical repair
#    itself, but may also suggest partial dehiscence. No definite masses or
#    vegetations are seen on the aortic valve. A bioprosthetic mitral valve
#    prosthesis is present. The prosthetic mitral leaflets appear normal.
#    The gradients are higher than expected for this type of prosthesis,
#    although this is almost certainly related to the amount of
#    regurgitation, rather than obstruction of the prosthesis. A moderate to
#    severe (3+) paravalvular mitral prosthesis [**Month/Day/Year 2400**] is present. No mass or
#    vegetation is seen on the mitral valve. Moderate [2+] tricuspid
#    regurgitation is seen. There is severe pulmonary artery systolic
#    hypertension. The end-diastolic pulmonic regurgitation velocity is
#    increased suggesting pulmonary artery diastolic hypertension. There is
#    a trivial/physiologic pericardial effusion.
#    .
#    IMPRESSION: Abnormal aortic prosthetic ring motion, concerning for
#    partial dehiscence. Moderate to severe paravalvular prosthetic mitral
#    regurgitation. Moderate tricuspid regurgitation. Mild biventricular
#    systolic dysfunction. Elevated left atrial pressures with left-to-right
#    interatrial shunting at rest. Severe pulmonary hypertension.
#    .
#    Assessment and Plan
#    Mr. [**Known lastname 5619**] is a 32 yo male with HIV/AIDs, CD4 of 5, here with LLE calf
#    pain/swelling, as well as nausea/vomiting/diarrhea and dyspnea on
#    exertion.
#    .
#    1.  LLE swelling.  Patient primary concern and reason for admission is
#    LLE swelling for three days and significant pain.  Pain is so great
#    that patient has difficulty placing calf on the bed.  High suspician
#    for DVT given patients sedentary lifestyle.  However, given bandemia,
#    may be due to cellulitis.  Heparinization in this patient would be
#    difficult given INR of 3 and thrombocytopenia, so may require IVC
#    filter placement if found to have DVT.
#    - LENIs to r/o DVT
#    - consider LLE x-ray if negative for DVT given severity of symptoms
#    - Vanco qHD to cover a cellulitis
#    - follow wbc, fever curve
#    - dilaudid for pain
#    .
#    2.  Dyspnea on exertion.  Patient reports DOE over the past few days to
#    weeks (poor historian so timeline not completely clear).  He denies
#    chest pain, cough, sputum production, but does endorse worsening LE
#    edema and chronic orthopnea.  DOE may be related to CHF in setting of
#    poor valvular function (AR with valve dehissence, MR, and TR).
#    However, given leg swelling, at risk for PE as well.  Of note, pt has
#    baseline RAD on EKG, but tacychardic here with no change in O2
#    requirements .  Pneumonia less likely given that there is not history
#    of fevers, cough, sputum production, however given immunosuppressed
#    state and bandemia, this remains a possibility.  CXR shows RLL collapse
#    but this could be secondary to pneumonia.  Given that CXR is not
#    typical for PCP, [**Name10 (NameIs) **] is reportedly on bactrim prophylaxis at home,
#    will hold off on empiric therapy for PCP at this point.
#    - induced sputum for gram stain and culture and PCP
#    [**Name Initial (PRE) **] blood cultures
#    - urine legionella
#    - fluid removal with HD (non-emergent)
#    - consider CTA if respiratory status does not improve with HD
#    .
#    3.  Nausea/vomiting.  Patient has history of nausea/vomiting, abdominal
#    pain and diarrhea.  Given CD4 count of 5, at risk for infectious
#    etiologies.  However, given history of endocarditis, may have septic
#    emboli resulting in mesenteric ischemia as well.  Given abdominal
#    tenderness in patient who is immunosuppressed from HIV and bandemia,
#    and elevated lactate, will further evaluate abdominal pain with
#    imaging.
#    - CT abd/pelvis to evaluate for ischemic or infectious colitis
#    - stool studies
#    .
#    4.  Elevated INR.  INR has never been greater than 2 and INR 1.6 last
#    month.  Currently not on anticoagulation.  Likely element of
#    malnutrition, but concern for chronic liver failure given history of
#    HBV, low albumin, low fibrinogen, low haptoglobin, hepatosplenomegaly
#    with ascites on prior imaging.  Heb B core Ab positive, but surface
#    antigen and Ab are negative likely representing prior infection.  HBV
#    and HCV viral load negative in [**10-25**].  Patient denies alcohol use, but
#    was reportedly taking 6+ percocet per day.  Liver failure may be due to
#    hepatic congestion due to CHF.
#    - check hep B viral load and serologies
#    - check hep C viral load and serologies
#    - check LFTs
#    - tyelenol level, NAC if positive
#    - vitamin K 5 mg po for three days
#    - abdomen CT to evaluate for hepatosplenomegaly and ascites
#    .
#    5.  Thrombocytopenia.  Platelet count has been declining over the last
#    year, now with more precipitous decline since [**2188-12-18**].  [**Month (only) 60**] be
#    secondary to splenomegaly versus HIV thrombocytopenia versus DIC.
#    Supsect that thrombocytopenia is due to worsening liver failure and
#    splenomegaly.  Although there are some labs that are concerning for DIC
#    (thrombocytopenia, low fibrinogen, 1+ schistocytes), this is more
#    likely due to liver failure (low haptoglobin, ascites,
#    hepatosplenomegaly).
#    - trend DIC labs
#    - trend platelets
#    .
#    6.  Bandemia.  Though WBC is not elevated and pt denies fevers, there
#    is concern for occult infection given patient
# s immunosuppressed state
#    and history of several infections (endocarditis, aortic root abscess,
#    eyelid infection).  Possible sources include pneumonia (RLL collapse on
#    CXR), colitis (nausea/vomiting/diarrhea), cellulitis (LLE erythema
#    though it is cool not warm). Patient does not make urine.  AVF is not
#    tender.
#    - induced sputum for gram stain/culture
#    - stool studies
#    - follow wbc, fever curve
#    - ID consult for Abx recommendations (?Vanco/Zosyn)
#    .
#    6.  HIV/AIDS.  CD4 count of 5. Per patient, would like another trial of
#    HAART but is awaiting arrival of meds, though not clear if this is
#    true.
#    - continue bactrim prophylaxis
#    .
#    7.  ESRD on HD. Now with evidence of fluid overload.
#    - continue HD
#    - renal aware that he is here
#    - continue sevelamer, calcium carbonate, cinacalcet
#    .
#    8.  Lactic acidosis.  Hypothermic in ED with bands, concerning for
#    sepsis etiology.  However, patient has not been hyoptensive here and
#    has evidence of liver failure by labs and imaging.
#    - trend lactate
#    - vanco for ?cellulitis on LLE
#    - consider empiric abx for resistant infections (?Vanco/zosyn)
#    .
#    9.       Hypertension.  On metoprolol, hydralaine, amlodipine, and
#    captopril at home for HTN.  Given elevated lactate, will hold
#    antihypertensives.
#    - hold antihypertensives
#    .
#    10.  Anion gap.  Likely secondary to renal failure and lactic acidosis.
#    - follow anion gap
#    .
#    11.  Volume overload.  Patient has elevated JVP with poorly functioning
#    aortic valve due to valve dehissence.
#    - volume removal with HD
#    - serial EKGs
#    .
#    12.  H/o endocarditis.  H/o of aortic valve endocarditis c/b abscess
#    and dehissence.  Currenly off abx for this.
#    - echo to evaluate valve function
#    .
#    13.    Elevated troponin.  No episode of chest pain and no current
#    chest pain.  EKG unchanged.  Elevated troponin is rise from prior, but
#    will trend.
#    -          trend CK, CK-MB, troponin
#    -          echo to evaluate for regional wall abnormalities
#    -          aspirin
#    .
#    FEN: No IVF, replete electrolytes, renal diet
#    .
#    Prophylaxis: Hold HSQ due to elevated INR, pneumoboots.
#    .
#    Access: PIVs x 2
#    .
#    Code: Patient previously discharged with hopsice care due to CPR being
#    deemed medically futile.  Patient now adamant that he would like to be
#    full code.
#    .
#    Communication: [**Name (NI) 5675**] [**Name (NI) 8374**] (sister) is HCP. Cell [**Telephone/Fax (1) 8375**].
#    [**Name2 (NI) **] [**Telephone/Fax (1) 8376**].  Mother is [**Name (NI) 8377**] [**Telephone/Fax (1) 8378**].
#    .
#    Disposition: ICU care for now
#    .
#    ICU Care
#    Nutrition:
#    Comments: NPO pending CT abd/pelvis results
#    Glycemic Control: Blood sugar well controlled
#    Lines:
#    18 Gauge - [**2189-2-24**] 12:31 PM
#    Prophylaxis:
#    DVT: Boots(Systemic anticoagulation: Other, therapeutic INR)
#    Stress ulcer: PPI
#    VAP:
#    Comments:
#    Communication: ICU consent signed Comments:
#    Code status: Full code
#    Disposition: ICU
#    ------ Protected Section ------
#    MICU ATTENDING ADDENDUM
#    I saw and examined the patient, and was physically present with the ICU
#    team for the key portions of the services provided. I agree with the
#    note above, including the assessment and plan. I would emphasize and
#    add the following points: 32M advanced HIV/AIDS (last CD4 5) c/b
#    AVR/MVR for endocarditis with known abscess, CHB c pacer c/b pocket
#    infection and removal, partial MV dehiscence and regurg, as well as
#    ESRD from FSGN. He is now admitted with LLE calf pain and swelling.
#    Also reports progressive DOE over weeks, and diarrhea/vomitting over
#    past few days. Treated in ED with antibiotics.
#    Exam notable for Tm BP 100/70 HR 94 RR 17 with sat 100 on 3L NC. Toxic
#    appearing, c/o RLE pain. JVD elevated Labs notable for WBC 4.8K, HCT
#    45, K+ 4.8, Cr 5.8, lactate 5.6, TB 3.9. CXR with RLL collapse, EKG s
#    acute changes.
#    Agree with plan to manage mild respiratory insufficiency and leg pain
#    with RLE USG to r/o DVT. If present, would favor filter, given multiple
#    risks for bleeding with coumadin. Will manage RLL collapse and possible
#    pneumonia with sputum GS/C+S, Legionella UCx, and induced sputum for
#    PCP/[**Doctor First Name **]. Unclear if there is an infection at this time, but will cover
#    for CAP, skin and possible bowel sources while awaiting culture data
#    and abd/pelvic CT for focal collection. Given AIDS, will consult ID,
#    and given elevated enzymes and prior endocarditis with paravalvular
#    [**Last Name (LF) 2400**], [**First Name3 (LF) 178**] recheck echo. His liver function is worse than prior,
#    unclear if this is due to viral infection, drugs / tylenol, congestion,
#    or low flow. Will follow serial studies and d/w liver team after
#    imaging. Remainder of plan as outlined above.
#    Patient is critically ill
#    Total time: 50 min
#    ------ Protected Section Addendum Entered By:[**Name (NI) 34**] [**Last Name (NamePattern1) 33**], MD
#    on:[**2189-2-24**] 05:44 PM ------
